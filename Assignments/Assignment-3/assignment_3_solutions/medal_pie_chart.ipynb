# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# number of gold medals
medals = [46, 38, 29, 24, 13, 11, 11, 8, 8, 7, 107]

# names of countries
countries = ["USA", "CHN", "GBR", "RUS", "KOR","GER", "FRA", "ITA", "HUN", "AUS", "OTHER"]

# colors to be used
colors = ['yellowgreen', 
          'gold',
          'lightskyblue',
          'lightcoral',
          'khaki',
          'bisque',
          'lavenderblush',
          'azure',
          'honeydew',
          'silver',
          'thistle']

# adjusting pie chart size
plt.figure(figsize=(8,8), dpi=96)

plt.pie(
    # x
    medals,
    # labels
    labels=countries,
    # color map
    colors=colors, 
    # location of percent on wedge
    pctdistance=0.85,
    # the fraction of the radius with which to offset each wedge
    explode=0.1 * np.ones(len(x)),
    # label the wedges with their numeric values
    autopct='%1.1f%%',
    # draw a shadow beneath the pie
    shadow=True,
    # rotates the start of the pie chart by 90 degrees
    startangle=90)

# adding title to the plot
plt.title('2012 Olympic gold medals (100XXXXXX)', fontsize=20)

# showing the final plot
plt.show()
